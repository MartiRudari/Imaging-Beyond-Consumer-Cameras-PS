# %% [markdown]
# <a href="https://colab.research.google.com/github/MartiRudari/Imaging-Beyond-Consumer-Cameras-PS/blob/main/NeRF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir -p /content/drive/MyDrive/nerfstudio_colab

# %%
# %cd /content/drive/MyDrive/nerfstudio_colab

# %%
# !git clone https://github.com/yenchenlin/nerf-pytorch.git

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install imageio imageio-ffmpeg matplotlib configargparse tqdm

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
# %cd /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch

# %% [markdown]
# CHAIR

# %%
# !ls /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/chair
# !ls /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/chair/train

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
    --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/chair.txt \
    --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/chair \
    --i_weights 500 \
    --i_print 100

# %%
# !python run_nerf.py \
  --config configs/chair.txt \
  --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/chair \
  --basedir /content/drive/MyDrive/nerfstudio_colab/logs \
  --expname blender_paper_chair \
  --render_only \
  --i_weights 12500

# %% [markdown]
# *TREX*

# %%
# !ls /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/trex/

# %%
# !apt-get update
# !apt-get install -y imagemagick

# %%
# !ls /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
  --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/fern.txt \
  --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/trex \
  --basedir /content/drive/MyDrive/nerfstudio_colab/logs \
  --expname trex_llff \
  --i_weights 500 \
  --i_print 100

# %%
# !mkdir -p /content/drive/MyDrive/nerfstudio_colab/logs/trex_llff/ckpts
# !mv /content/drive/MyDrive/nerfstudio_colab/logs/trex_llff/021000.tar \
      /content/drive/MyDrive/nerfstudio_colab/logs/trex_llff/ckpts/

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
    --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/fern.txt \
    --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/trex \
    --basedir /content/drive/MyDrive/nerfstudio_colab/logs \
    --expname trex_llff \
    --i_weights 21000 \
    --render_only

# %% [markdown]
# LEGO

# %%
# !ls /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/lego
# !ls /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/lego/train

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
    --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/lego.txt \
    --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/lego \
    --i_weights 500 \
    --i_print 100

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
  --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/lego.txt \
  --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/lego \
  --basedir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/logs \
  --expname blender_paper_lego \
  --render_only \
  --i_weights 14500

# %% [markdown]
# PINE 360

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
  --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/pine.txt \
  --i_weights 500 \
  --i_print 100

# %%
# !python /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/run_nerf.py \
  --config /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/configs/pine.txt \
  --datadir /content/drive/MyDrive/nerfstudio_colab/nerf-pytorch/nerf_real_360/pinecone \
  --basedir /content/drive/MyDrive/nerfstudio_colab/logs \
  --expname pine_paper \
  --render_only \
  --i_weights 47000
